# %% [markdown]
# <a href="https://colab.research.google.com/github/venpopov/DataSciencePsychUZH/blob/main/Homeworks/Homework1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Homework 1: Setting up GitHub and Jupyter Notebook
#
# Throughout the course you will be using GitHub and Jupyter Notebooks to submit your work. Your first assignment is to set both of these up so that you are ready for the future assignments.

# %% [markdown]
# ### GitHub
# 1. Open the Tutorial1_Version_control_Git_GitHub.ipynb notebook in the Tutorials folder of this repository. Use it to do the next steps
# 2. Create a GitHub account and create a new repository with the name your_last_name_DSP_S21 (replace 'your_last_name' with your own last name!)
# 3. Add the user *venpopov* as a collaborator
# 4. Clone the newly created repository on your computer
#
# **Note**: In the future you will push all of your assignments to this repository

# %% [markdown]
# ### Jupyter Notebooks
#
# Jupyter Notebooks facilitate reproducible science by allowing you to integrate narrative text, analysis code and figures. You can share the final document with anyone and they will be able to interact with your code and reproduce your analyses if need be. For this homework, you have to:
#
# 1. Install Jupyter Notebooks on your computer (I recommend using the miniconda option, see link) - https://jupyter.org/install.html
# 2. Install the R kernel for jupyter notebooks - https://www.datacamp.com/community/blog/jupyter-notebook-r
# 3. Make a new Jupyter notebook with an R kernel titled: Homework1.ipynb

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Become familiar with the Jupyter Notebook interface by a) exploring it on your own or b) reading through https://jupyter-notebook.readthedocs.io/en/stable/notebook.html
# 5. Make a markdown text cell and type "I'm integrating text, code and figures in a single document!"
# 6. Make an R code cell with the following content:

# %%
x <- rnorm(1000)
y <- x**2+rnorm(1000,0,1)
plot(x,y)
# Out:
# plot without title

# %% [markdown]
# 6. Push your Jupyter notebook to the repository you made on GitHub
# 7. Email me a link to the notebook
